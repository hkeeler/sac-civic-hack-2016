# %% [markdown]
# # Sacramento Promise Zone

# %%
import pandas as pd
import folium

# %% [markdown]
# ## Load default map at approprate location and zoom

# %%
def build_base_map():
    return folium.Map(location=[38.57, -121.45], zoom_start=12)

build_base_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# ## Add Promise Zone shapefile

# %%
pz_geojson='./data/code4sac/PromiseZone.geojson'

pz_map.choropleth(geo_path=pz_geojson)
pz_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
pz_map = build_base_map()
pz_map.choropleth(geo_path=pz_geojson, fill_opacity=0, line_weight=4, line_color='blue', line_opacity=1)
pz_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
